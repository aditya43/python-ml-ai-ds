# %% [markdown]
# # Speech Recognition | Create word embeddings
# ### Aditya Hajare | https://github.com/aditya43

# %%
import numpy as np
from IPython.display import display, HTML
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import pandas as pd
import re

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adiinviter/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Read data from file.

# %%
def get_file_data(stop_word_removal='no'):
    file_contents = []
    with open('/Users/adiinviter/work/AdityaHajare/Assignments/w2v.txt') as f:
        file_contents = f.read()
    text = []
    for val in file_contents.split('.'):
        sent = re.findall("[A-Za-z]+", val)
        line = ''
        for words in sent:
            
            if stop_word_removal == 'yes': 
                if len(words) > 1 and words not in stop_words:
                    line = line + ' ' + words
            else:
                if len(words) > 1 :
                    line = line + ' ' + words
        text.append(line)
    return text

# %% [markdown]
# ## Generate variables
#
# ##### word_to_index: A dictionary mapping each word to an integer value {'aditya': 0, 'hajare': 1}
# ##### index_to_word: A dictionary mapping each word to an integer value {0: 'aditya', 1: 'hajare'}
# ##### corpus: The entire data consisting of all the words
# ##### vocab_size: Number of unique words in the corpus

# %%
def generate_dictinoary_data(text):
    word_to_index= dict()
    index_to_word = dict()
    corpus = []
    count = 0
    vocab_size = 0
    
    for row in text:
        for word in row.split():
            word = word.lower()
            corpus.append(word)
            if word_to_index.get(word) == None:
                word_to_index.update ( {word : count})
                index_to_word.update ( {count : word })
                count  += 1
    vocab_size = len(word_to_index)
    length_of_corpus = len(corpus)
    
    return word_to_index,index_to_word,corpus,vocab_size,length_of_corpus

# %% [markdown]
# ## Testing generate_dictinoary_data() definition.

# %%
text = get_file_data()
word_to_index,index_to_word,corpus,vocab_size,length_of_corpus = generate_dictinoary_data(text)
print('Number of unique words:' , vocab_size)
print('word_to_index : ',word_to_index)
print('index_to_word : ',index_to_word)
print('corpus:',corpus)
print('Length of corpus :',length_of_corpus)
# Out:
# Number of unique words: 261
# word_to_index :  {'in': 0, 'linguistics': 1, 'word': 2, 'embeddings': 3, 'were': 4, 'discussed': 5, 'the': 6, 'research': 7, 'area': 8, 'of': 9, 'distributional': 10, 'semantics': 11, 'it': 12, 'aims': 13, 'to': 14, 'quantify': 15, 'and': 16, 'categorize': 17, 'semantic': 18, 'similarities': 19, 'between': 20, 'linguistic': 21, 'items': 22, 'based': 23, 'on': 24, 'their': 25, 'properties': 26, 'large': 27, 'samples': 28, 'language': 29, 'data': 30, 'underlying': 31, 'idea': 32, 'that': 33, 'is': 34, 'characterized': 35, 'by': 36, 'company': 37, 'keeps': 38, 'was': 39, 'popularized': 40, 'firth': 41, 'technique': 42, 'representing': 43, 'words': 44, 'as': 45, 'vectors': 46, 'has': 47, 'roots': 48, 'with': 49, 'development': 50, 'vector': 51, 'space': 52, 'model': 53, 'for': 54, 'information': 55, 'retrieval': 56, 'reducing': 57, 'number': 58, 'dimensions': 59, 'using': 60, 'singular': 61, 'value': 62, 'decomposition': 63, 'then': 64, 'led': 65, 'introduction': 66, 'latent': 67, 'analysis': 68, 'late': 69, 'bengio': 70, 'et': 71, 'al': 72, 'provided': 73, 'series': 74, 'papers': 75, 'neural': 76, 'probabilistic': 77, 'models': 78, 'reduce': 79, 'high': 80, 'dimensionality': 81, 'representations': 82, 'contexts': 83, 'learning': 84, 'distributed': 85, 'representation': 86, 'come': 87, 'two': 88, 'different': 89, 'styles': 90, 'one': 91, 'which': 92, 'are': 93, 'expressed': 94, 'co': 95, 'occurring': 96, 'another': 97, 'occur': 98, 'these': 99, 'studied': 100, 'lavelli': 101, 'roweis': 102, 'saul': 103, 'published': 104, 'science': 105, 'how': 106, 'use': 107, 'locally': 108, 'linear': 109, 'embedding': 110, 'lle': 111, 'discover': 112, 'dimensional': 113, 'structures': 114, 'developed': 115, 'gradually': 116, 'really': 117, 'took': 118, 'off': 119, 'after': 120, 'partly': 121, 'because': 122, 'important': 123, 'advances': 124, 'had': 125, 'been': 126, 'made': 127, 'since': 128, 'quality': 129, 'training': 130, 'speed': 131, 'there': 132, 'many': 133, 'branches': 134, 'groups': 135, 'working': 136, 'team': 137, 'at': 138, 'google': 139, 'tomas': 140, 'mikolov': 141, 'created': 142, 'vec': 143, 'toolkit': 144, 'can': 145, 'train': 146, 'faster': 147, 'than': 148, 'previous': 149, 'approaches': 150, 'most': 151, 'new': 152, 'techniques': 153, 'rely': 154, 'network': 155, 'architecture': 156, 'instead': 157, 'more': 158, 'traditional': 159, 'gram': 160, 'unsupervised': 161, 'limitations': 162, 'main': 163, 'general': 164, 'possible': 165, 'meanings': 166, 'conflated': 167, 'into': 168, 'single': 169, 'sense': 170, 'solution': 171, 'this': 172, 'problem': 173, 'individual': 174, 'represented': 175, 'distinct': 176, 'biological': 177, 'sequences': 178, 'biovectors': 179, 'grams': 180, 'dna': 181, 'rna': 182, 'proteins': 183, 'bioinformatics': 184, 'applications': 185, 'have': 186, 'proposed': 187, 'asgari': 188, 'mofrad': 189, 'named': 190, 'bio': 191, 'biovec': 192, 'refer': 193, 'protein': 194, 'protvec': 195, 'amino': 196, 'acid': 197, 'gene': 198, 'genevec': 199, 'be': 200, 'widely': 201, 'used': 202, 'deep': 203, 'proteomics': 204, 'genomics': 205, 'results': 206, 'presented': 207, 'suggest': 208, 'characterize': 209, 'terms': 210, 'biochemical': 211, 'biophysical': 212, 'interpretations': 213, 'patterns': 214, 'thought': 215, 'an': 216, 'extension': 217, 'entire': 218, 'sentences': 219, 'or': 220, 'even': 221, 'documents': 222, 'some': 223, 'researchers': 224, 'hope': 225, 'improve': 226, 'machine': 227, 'translation': 228, 'software': 229, 'includes': 230, 'stanford': 231, 'university': 232, 'glove': 233, 'allennlp': 234, 'elmo': 235, 'fasttext': 236, 'gensim': 237, 'indra': 238, 'deeplearning': 239, 'principal': 240, 'component': 241, 'pca': 242, 'stochastic': 243, 'neighbour': 244, 'sne': 245, 'both': 246, 'spaces': 247, 'visualize': 248, 'clusters': 249, 'examples': 250, 'application': 251, 'instance': 252, 'also': 253, 'calculate': 254, 'text': 255, 'corpora': 256, 'sketch': 257, 'engine': 258, 'available': 259, 'online': 26 ...
# index_to_word :  {0: 'in', 1: 'linguistics', 2: 'word', 3: 'embeddings', 4: 'were', 5: 'discussed', 6: 'the', 7: 'research', 8: 'area', 9: 'of', 10: 'distributional', 11: 'semantics', 12: 'it', 13: 'aims', 14: 'to', 15: 'quantify', 16: 'and', 17: 'categorize', 18: 'semantic', 19: 'similarities', 20: 'between', 21: 'linguistic', 22: 'items', 23: 'based', 24: 'on', 25: 'their', 26: 'properties', 27: 'large', 28: 'samples', 29: 'language', 30: 'data', 31: 'underlying', 32: 'idea', 33: 'that', 34: 'is', 35: 'characterized', 36: 'by', 37: 'company', 38: 'keeps', 39: 'was', 40: 'popularized', 41: 'firth', 42: 'technique', 43: 'representing', 44: 'words', 45: 'as', 46: 'vectors', 47: 'has', 48: 'roots', 49: 'with', 50: 'development', 51: 'vector', 52: 'space', 53: 'model', 54: 'for', 55: 'information', 56: 'retrieval', 57: 'reducing', 58: 'number', 59: 'dimensions', 60: 'using', 61: 'singular', 62: 'value', 63: 'decomposition', 64: 'then', 65: 'led', 66: 'introduction', 67: 'latent', 68: 'analysis', 69: 'late', 70: 'bengio', 71: 'et', 72: 'al', 73: 'provided', 74: 'series', 75: 'papers', 76: 'neural', 77: 'probabilistic', 78: 'models', 79: 'reduce', 80: 'high', 81: 'dimensionality', 82: 'representations', 83: 'contexts', 84: 'learning', 85: 'distributed', 86: 'representation', 87: 'come', 88: 'two', 89: 'different', 90: 'styles', 91: 'one', 92: 'which', 93: 'are', 94: 'expressed', 95: 'co', 96: 'occurring', 97: 'another', 98: 'occur', 99: 'these', 100: 'studied', 101: 'lavelli', 102: 'roweis', 103: 'saul', 104: 'published', 105: 'science', 106: 'how', 107: 'use', 108: 'locally', 109: 'linear', 110: 'embedding', 111: 'lle', 112: 'discover', 113: 'dimensional', 114: 'structures', 115: 'developed', 116: 'gradually', 117: 'really', 118: 'took', 119: 'off', 120: 'after', 121: 'partly', 122: 'because', 123: 'important', 124: 'advances', 125: 'had', 126: 'been', 127: 'made', 128: 'since', 129: 'quality', 130: 'training', 131: 'speed', 132: 'there', 133: 'many', 134: 'branches', 135: 'groups', 136: 'working', 137: 'team', 138: 'at', 139: 'google', 140: 'tomas', 141: 'mikolov', 142: 'created', 143: 'vec', 144: 'toolkit', 145: 'can', 146: 'train', 147: 'faster', 148: 'than', 149: 'previous', 150: 'approaches', 151: 'most', 152: 'new', 153: 'techniques', 154: 'rely', 155: 'network', 156: 'architecture', 157: 'instead', 158: 'more', 159: 'traditional', 160: 'gram', 161: 'unsupervised', 162: 'limitations', 163: 'main', 164: 'general', 165: 'possible', 166: 'meanings', 167: 'conflated', 168: 'into', 169: 'single', 170: 'sense', 171: 'solution', 172: 'this', 173: 'problem', 174: 'individual', 175: 'represented', 176: 'distinct', 177: 'biological', 178: 'sequences', 179: 'biovectors', 180: 'grams', 181: 'dna', 182: 'rna', 183: 'proteins', 184: 'bioinformatics', 185: 'applications', 186: 'have', 187: 'proposed', 188: 'asgari', 189: 'mofrad', 190: 'named', 191: 'bio', 192: 'biovec', 193: 'refer', 194: 'protein', 195: 'protvec', 196: 'amino', 197: 'acid', 198: 'gene', 199: 'genevec', 200: 'be', 201: 'widely', 202: 'used', 203: 'deep', 204: 'proteomics', 205: 'genomics', 206: 'results', 207: 'presented', 208: 'suggest', 209: 'characterize', 210: 'terms', 211: 'biochemical', 212: 'biophysical', 213: 'interpretations', 214: 'patterns', 215: 'thought', 216: 'an', 217: 'extension', 218: 'entire', 219: 'sentences', 220: 'or', 221: 'even', 222: 'documents', 223: 'some', 224: 'researchers', 225: 'hope', 226: 'improve', 227: 'machine', 228: 'translation', 229: 'software', 230: 'includes', 231: 'stanford', 232: 'university', 233: 'glove', 234: 'allennlp', 235: 'elmo', 236: 'fasttext', 237: 'gensim', 238: 'indra', 239: 'deeplearning', 240: 'principal', 241: 'component', 242: 'pca', 243: 'stochastic', 244: 'neighbour', 245: 'sne', 246: 'both', 247: 'spaces', 248: 'visualize', 249: 'clusters', 250: 'examples', 251: 'application', 252: 'instance', 253: 'also', 254: 'calculate', 255: 'text', 256: 'corpora', 257: 'sketch', 258: 'engine', 259: 'available', 260: 'online ...
# corpus: ['in', 'linguistics', 'word', 'embeddings', 'were', 'discussed', 'in', 'the', 'research', 'area', 'of', 'distributional', 'semantics', 'it', 'aims', 'to', 'quantify', 'and', 'categorize', 'semantic', 'similarities', 'between', 'linguistic', 'items', 'based', 'on', 'their', 'distributional', 'properties', 'in', 'large', 'samples', 'of', 'language', 'data', 'the', 'underlying', 'idea', 'that', 'word', 'is', 'characterized', 'by', 'the', 'company', 'it', 'keeps', 'was', 'popularized', 'by', 'firth', 'the', 'technique', 'of', 'representing', 'words', 'as', 'vectors', 'has', 'roots', 'in', 'the', 'with', 'the', 'development', 'of', 'the', 'vector', 'space', 'model', 'for', 'information', 'retrieval', 'reducing', 'the', 'number', 'of', 'dimensions', 'using', 'singular', 'value', 'decomposition', 'then', 'led', 'to', 'the', 'introduction', 'of', 'latent', 'semantic', 'analysis', 'in', 'the', 'late', 'in', 'bengio', 'et', 'al', 'provided', 'in', 'series', 'of', 'papers', 'the', 'neural', 'probabilistic', 'language', 'models', 'to', 'reduce', 'the', 'high', 'dimensionality', 'of', 'words', 'representations', 'in', 'contexts', 'by', 'learning', 'distributed', 'representation', 'for', 'words', 'bengio', 'et', 'al', 'word', 'embeddings', 'come', 'in', 'two', 'different', 'styles', 'one', 'in', 'which', 'words', 'are', 'expressed', 'as', 'vectors', 'of', 'co', 'occurring', 'words', 'and', 'another', 'in', 'which', 'words', 'are', 'expressed', 'as', 'vectors', 'of', 'linguistic', 'contexts', 'in', 'which', 'the', 'words', 'occur', 'these', 'different', 'styles', 'are', 'studied', 'in', 'lavelli', 'et', 'al', 'roweis', 'and', 'saul', 'published', 'in', 'science', 'how', 'to', 'use', 'locally', 'linear', 'embedding', 'lle', 'to', 'discover', 'representations', 'of', 'high', 'dimensional', 'data', 'structures', 'the', 'area', 'developed', 'gradually', 'and', 'really', 'took', 'off', 'after', 'partly', 'because', 'important', 'advances', 'had', 'been', 'made', 'since', 'then', 'on', 'the', 'quality', 'of', 'vectors', 'and', 'the', 'training', 'speed', 'of', 'the', 'model', 'there', 'are', 'many', 'branches', 'and', 'many', 'research', 'groups', 'working', 'on', 'word', 'embeddings', 'in', 'team', 'at', 'google', 'led', 'by', 'tomas', 'mikolov', 'created', 'word', 'vec', 'word', 'embedding', 'toolkit', 'which', 'can', 'train', 'vector', 'space', 'models', 'faster', 'than', 'the', 'previous', 'approaches', 'most', 'new', 'word', 'embedding', 'techniques', 'rely', 'on', 'neural', 'network', 'architecture', 'instead', 'of', 'more', 'traditional', 'gram', 'models', 'and', 'unsupervised', 'learning', 'limitations', 'one', 'of', 'the', 'main', 'limitations', 'of', 'word', 'embeddings', 'word', 'vector', 'space', 'models', 'in', 'general', 'is', 'that', 'possible', 'meanings', 'of', 'word', 'are', 'conflated', 'into', 'single', 'representation', 'single', 'vector', 'in', 'the', 'semantic', 'space', 'sense', 'embeddings', 'are', 'solution', 'to', 'this', 'problem', 'individual', 'meanings', 'of', 'words', 'are', 'represented', 'as', 'distinct', 'vectors', 'in', 'the', 'space', 'for', 'biological', 'sequences', 'biovectors', 'word', 'embeddings', 'for', 'grams', 'in', 'biological', 'sequences', 'dna', 'rna', 'and', 'proteins', 'for', 'bioinformatics', 'applications', 'have', 'been', 'proposed', 'by', 'asgari', 'and', 'mofrad', 'named', 'bio', 'vectors', 'biovec', 'to', 'refer', 'to', 'biological', 'sequences', 'in', 'general', 'with', 'protein', 'vectors', 'protvec', 'for', 'proteins', 'amino', 'acid', 'sequences', 'and', 'gene', 'vectors', 'genevec', 'for', 'gene', 'sequences', 'this', 'representation', 'can', 'be', 'widely', 'used', 'in', 'applications', 'of', 'deep', 'learning', 'in', 'proteomics', 'and', 'genomics', 'the', 'results', 'presented', 'by', 'asgari', 'and', 'mofrad', 'suggest', 'that', 'biovectors', 'can', 'characterize', 'biological', 'sequences', 'in', 'terms', 'of', 'biochemical', 'and', 'biophysical', 'interpretations', 'of',  ...
# Length of corpus : 524

# %% [markdown]
# ## Generate training data
#
# #### The training data is in the following format :
#
# #####   Example:
#
# #####   Window size = 2, Vocab size = 9
#
#
# #####   We will set the indicies as 1 according to the word_to_index dict i.e natural: 0, so we set the 0th index as 1 to denote natural
#
# #####   Target word = best
# #####   Context words = (way,to)
# #####   Target_word_one_hot_vector = [1, 0, 0, 0, 0, 0, 0, 0, 0]
# #####   Context_word_one_hot_vector = [0, 1, 1, 0, 0, 0, 0, 0, 0]
#
# #####   Target word = way
# #####   Context words = (best,to,success)
# #####   Target_word_one_hot_vector = [0, 1, 0, 0, 0, 0, 0, 0, 0]
# #####   Context_word_one_hot_vector= [1, 0, 1, 1, 0, 0, 0, 0, 0]

# %%
def get_one_hot_vectors(target_word,context_words,vocab_size,word_to_index):    
    #Create an array of size = vocab_size filled with zeros
    trgt_word_vector = np.zeros(vocab_size)
    
    #Get the index of the target_word according to the dictionary word_to_index. 
    #If target_word = best, the index according to the dictionary word_to_index is 0. 
    #So the one hot vector will be [1, 0, 0, 0, 0, 0, 0, 0, 0]
    index_of_word_dictionary = word_to_index.get(target_word) 
    
    #Set the index to 1
    trgt_word_vector[index_of_word_dictionary] = 1
    
    #Repeat same steps for context_words but in a loop
    ctxt_word_vector = np.zeros(vocab_size)
    
    
    for word in context_words:
        index_of_word_dictionary = word_to_index.get(word) 
        ctxt_word_vector[index_of_word_dictionary] = 1
        
    return trgt_word_vector,ctxt_word_vector

# %%
#Note : Below comments for trgt_word_index, ctxt_word_index are with the above sample text for understanding the code flow

def generate_training_data(corpus,window_size,vocab_size,word_to_index,length_of_corpus,sample=None):

    training_data =  []
    training_sample_words =  []
    for i,word in enumerate(corpus):

        index_target_word = i
        target_word = word
        context_words = []

        #when target word is the first word
        if i == 0:  

            # trgt_word_index:(0), ctxt_word_index:(1,2)
            context_words = [corpus[x] for x in range(i + 1 , window_size + 1)] 


        #when target word is the last word
        elif i == len(corpus)-1:

            # trgt_word_index:(9), ctxt_word_index:(8,7), length_of_corpus = 10
            context_words = [corpus[x] for x in range(length_of_corpus - 2 ,length_of_corpus -2 - window_size  , -1 )]

        #When target word is the middle word
        else:

            #Before the middle target word
            before_target_word_index = index_target_word - 1
            for x in range(before_target_word_index, before_target_word_index - window_size , -1):
                if x >=0:
                    context_words.extend([corpus[x]])

            #After the middle target word
            after_target_word_index = index_target_word + 1
            for x in range(after_target_word_index, after_target_word_index + window_size):
                if x < len(corpus):
                    context_words.extend([corpus[x]])


        trgt_word_vector,ctxt_word_vector = get_one_hot_vectors(target_word,context_words,vocab_size,word_to_index)
        training_data.append([trgt_word_vector,ctxt_word_vector])   
        
        if sample is not None:
            training_sample_words.append([target_word,context_words])   
        
    return training_data,training_sample_words

# %%
window_size = 2
training_data,training_sample_words = generate_training_data(corpus,2,vocab_size,word_to_index,length_of_corpus,'yes')

# %%
for i in range(len(training_data)):
    print('*' * 50)
    # print('Target word:%s . Target vector: %s ' %(training_sample_words[i][0],training_data[i][0]))
    # print('Context word:%s . Context  vector: %s ' %(training_sample_words[i][1],training_data[i][1]))
    print('Target word:%s' %(training_sample_words[i][0]))
    print('Context word:%s' %(training_sample_words[i][1]))
# Out:
# **************************************************
# Target word:in
# Context word:['linguistics', 'word']
# **************************************************
# Target word:linguistics
# Context word:['in', 'word', 'embeddings']
# **************************************************
# Target word:word
# Context word:['linguistics', 'in', 'embeddings', 'were']
# **************************************************
# Target word:embeddings
# Context word:['word', 'linguistics', 'were', 'discussed']
# **************************************************
# Target word:were
# Context word:['embeddings', 'word', 'discussed', 'in']
# **************************************************
# Target word:discussed
# Context word:['were', 'embeddings', 'in', 'the']
# **************************************************
# Target word:in
# Context word:['discussed', 'were', 'the', 'research']
# **************************************************
# Target word:the
# Context word:['in', 'discussed', 'research', 'area']
# **************************************************
# Target word:research
# Context word:['the', 'in', 'area', 'of']
# **************************************************
# Target word:area
# Context word:['research', 'the', 'of', 'distributional']
# **************************************************
# Target word:of
# Context word:['area', 'research', 'distributional', 'semantics']
# **************************************************
# Target word:distributional
# Context word:['of', 'area', 'semantics', 'it']
# **************************************************
# Target word:semantics
# Context word:['distributional', 'of', 'it', 'aims']
# **************************************************
# Target word:it
# Context word:['semantics', 'distributional', 'aims', 'to']
# **************************************************
# Target word:aims
# Context word:['it', 'semantics', 'to', 'quantify']
# **************************************************
# Target word:to
# Context word:['aims', 'it', 'quantify', 'and']
# **************************************************
# Target word:quantify
# Context word:['to', 'aims', 'and', 'categorize']
# **************************************************
# Target word:and
# Context word:['quantify', 'to', 'categorize', 'semantic']
# **************************************************
# Target word:categorize
# Context word:['and', 'quantify', 'semantic', 'similarities']
# **************************************************
# Target word:semantic
# Context word:['categorize', 'and', 'similarities', 'between']
# **************************************************
# Target word:similarities
# Context word:['semantic', 'categorize', 'between', 'linguistic']
# **************************************************
# Target word:between
# Context word:['similarities', 'semantic', 'linguistic', 'items']
# **************************************************
# Target word:linguistic
# Context word:['between', 'similarities', 'items', 'based']
# **************************************************
# Target word:items
# Context word:['linguistic', 'between', 'based', 'on']
# **************************************************
# Target word:based
# Context word:['items', 'linguistic', 'on', 'their']
# **************************************************
# Target word:on
# Context word:['based', 'items', 'their', 'distributional']
# **************************************************
# Target word:their
# Context word:['on', 'based', 'distributional', 'properties']
# **************************************************
# Target word:distributional
# Context word:['their', 'on', 'properties', 'in']
# **************************************************
# Target word:properties
# Context word:['distributional', 'their', 'in', 'large']
# **************************************************
# Target word:in
# Context word:['properties', 'distributional', 'large', 'samples']
# **************************************************
# Target word:large
# Context word:['in', 'properties', 'samples', 'of']
# **************************************************
# Target word:samples
# Context word:['large', 'in', 'of', 'language']
# **************************************************
# Target word:of
# Context word:['samples', 'large', 'language', 'data']
# **************************************************
# Target word:language
# Context word:['of', 'samples', 'data', 'the']
# **************************************************
# Target word:data
# Context word:['language', 'of', 'the', 'underlying']
# **************************************************
# Target word:the
# Context word:['data', 'language', 'underlying', 'idea']
# **************************************************
# Target word:underlying
# Context word:['the', 'data', 'idea', 'that']
# **************************************************
# Target word:idea
# Context word:['underlying', 'the', 'that', 'word']
# **************************************************
# Target word:that
# Context word:['idea', 'underlying', 'word', 'is']
# **************************************************
# Target word:word
# Context word:['that', 'idea', 'is', 'characterized']
# **************************************************
# Target word:is
# Context word:['word', 'that', 'characterized', 'by']
# **************************************************
# Target word:characterized
# Context word:['is', 'word', 'by', 'the']
# **************************************************
# Target word:by
# Context word:['characterized', 'is', 'the', 'company']
# **************************************************
# Target word:the
# Context word:['by', 'characterized', 'company', 'it']
# **************************************************
# Target word:company
# Context word:['the', 'by', 'it', 'keeps']
# **************************************************
# Target word:it
# Context word:['company', 'the', 'keeps', 'was']
# **************************************************
# Target word:keeps
# Context word:['it', 'company', 'was', 'popularized']
# **************************************************
# Target word:was
# Context word:['keeps', 'it', 'popularized', 'by']
# **************************************************
# Target word:popularized
# Context word:['was', 'keeps', 'by', 'firth']
# **************************************************
# Target word:by
# Context word:['popularized', 'was', 'firth', 'the']
# **************************************************
# Target word:firth
# Context word:['by', 'popularized', 'the', 'technique']
# **************************************************
# Target word:the
# Context word:['firth', 'by', 'technique', 'of']
# **************************************************
# Target word:technique
# Context word:['the', 'firth', 'of', 'representing']
# **************************************************
# Target word:of
# Context word:['technique', 'the', 'representing', 'words']
# **************************************************
# Target word:representing
# Context word:['of', 'technique', 'words', 'as']
# **************************************************
# Target word:words
# Context word:['representing', 'of', 'as', 'vectors']
# **************************************************
# Target word:as
# Context word:['words', 'representing', 'vectors', 'has']
# **************************************************
# Target word:vectors
# Context word:['as', 'words', 'has', 'roots']
# **************************************************
# Target word:has
# Context word:['vectors', 'as', 'roots', 'in']
# **************************************************
# Target word:roots
# Context word:['has', 'vectors', 'in', 'the']
# **************************************************
# Target word:in
# Context word:['roots', 'has', 'the', 'with']
# **************************************************
# Target word:the
# Context word:['in', 'roots', 'with', 'the']
# **************************************************
# Target word:with
# Context word:['the', 'in', 'the', 'development']
# **************************************************
# Target word:the
# Context word:['with', 'the', 'development', 'of']
# **************************************************
# Target word:development
# Context word:['the', 'with', 'of', 'the']
# **************************************************
# Target word:of
# Context word:['development', 'the', 'the', 'vector']
# **************************************************
# Target word:the
# Context word:['of', 'development', 'vector', 'space']
# **************************************************
# Target word:vector
# Context word:['the', 'of', 'space', 'model']
# **************************************************
# Target word:space
# Context word:['vector', 'the', 'model', 'for']
# **************************************************
# Target word:model
# Context word:['space', 'vector', 'for', 'information']
# **************************************************
# Target word:for
# Context word:['model', 'space', 'information', 'retrieval']
# **************************************************
# Target word:information
# Context word:['for', 'model', 'retrieval', 'reducing']
# **************************************************
# Target word:retrieval
# Context word:['information', 'for', 'reducing', 'the']
# **************************************************
# Target word:reducing
# Context word:['retrieval', 'information', 'the', 'number']
# **************************************************
# Target word:the
# Context word:['reducing', 'retrieval', 'number', 'of']
# **************************************************
# Target word:number
# Context word:['the', 'reducing', 'of', 'dimensions']
# **************************************************
# Target word:of
# Context word:['number', 'the', 'dimensions', 'using']
# **************************************************
# Target word:dimensions
# Context word:['of', 'number', 'using', 'singular']
# **************************************************
# Target word:using
# Context word:['dimensions', 'of', 'singular', 'value']
# **************************************************
# Target word:singular
# Context word:['using', 'dimensions', 'value', 'decomposition']
# **************************************************
# Target word:value
# Context word:['singular', 'using', 'decomposition', 'then']
# **************************************************
# Target word:decomposition
# Context word:['value', 'singular', 'then', 'led']
# **************************************************
# Target word:then
# Context word:['decomposition', 'value', 'led', 'to']
# **************************************************
# Target word:led
# Context word:['then', 'decomposition', 'to', 'the']
# **************************************************
# Target word:to
# Context word:['led', 'then', 'the', 'introduction']
# **************************************************
# Target word:the
# Context word:['to', 'led', 'introduction', 'of']
# **************************************************
# Target word:introduction
# Context word:['the', 'to', 'of', 'latent']
# **************************************************
# Target word:of
# Context word:['introduction', 'the', 'latent', 'semantic']
# **************************************************
# Target word:latent
# Context word:['of', 'introduction', 'semantic', 'analysis']
# **************************************************
# Target word:semantic
# Context word:['latent', 'of', 'analysis', 'in']
# **************************************************
# Target word:analysis
# Context word:['semantic', 'latent', 'in', 'the']
# **************************************************
# Target word:in
# Context word:['analysis', 'semantic', 'the', 'late']
# **************************************************
# Target word:the
# Context word:['in', 'analysis', 'late', 'in']
# **************************************************
# Target word:late
# Context word:['the', 'in', 'in', 'bengio']
# **************************************************
# Target word:in
# Context word:['late', 'the', 'bengio', 'et']
# **************************************************
# Target word:bengio
# Context word:['in', 'late', 'et', 'al']
# **************************************************
# Target word:et
# Context word:['bengio', 'in', 'al', 'provided']
# **************************************************
# Target word:al
# Context word:['et', 'bengio', 'provided', 'in']
# **************************************************
# Target word:provided
# Context word:['al', 'et', 'in', 'series']
# **************************************************
# Target word:in
# Context word:['provided', 'al', 'series', 'of']
# **************************************************
# Target word:series
# Context word:['in', 'provided', 'of', 'papers']
# **************************************************
# Target word:of
# Context word:['series', 'in', 'papers', 'the']
# **************************************************
# Target word:papers
# Context word:['of', 'series', 'the', 'neural']
# **************************************************
# Target word:the
# Context word:['papers', 'of', 'neural', 'probabilistic']
# **************************************************
# Target word:neural
# Context word:['the', 'papers', 'probabilistic', 'language']
# **************************************************
# Target word:probabilistic
# Context word:['neural', 'the', 'language', 'models']
# **************************************************
# Target word:language
# Context word:['probabilistic', 'neural', 'models', 'to']
# **************************************************
# Target word:models
# Context word:['language', 'probabilistic', 'to', 'reduce']
# **************************************************
# Target word:to
# Context word:['models', 'language', 'reduce', 'the']
# **************************************************
# Target word:reduce
# Context word:['to', 'models', 'the', 'high']
# **************************************************
# Target word:the
# Context word:['reduce', 'to', 'high', 'dimensionality']
# **************************************************
# Target word:high
# Context word:['the', 'reduce', 'dimensionality', 'of']
# **************************************************
# Target word:dimensionality
# Context word:['high', 'the', 'of', 'words']
# **************************************************
# Target word:of
# Context word:['dimensionality', 'high', 'words', 'representations']
# **************************************************
# Target word:words
# Context word:['of', 'dimensionality', 'representations', 'in']
# **************************************************
# Target word:representations
# Context word:['words', 'of', 'in', 'contexts']
# **************************************************
# Target word:in
# Context word:['representations', 'words', 'contexts', 'by']
# **************************************************
# Target word:contexts
# Context word:['in', 'representations', 'by', 'learning']
# **************************************************
# Target word:by
# Context word:['contexts', 'in', 'learning', 'distributed']
# **************************************************
# Target word:learning
# Context word:['by', 'contexts', 'distributed', 'representation']
# **************************************************
# Target word:distributed
# Context word:['learning', 'by', 'representation', 'for']
# **************************************************
# Target word:representation
# Context word:['distributed', 'learning', 'for', 'words']
# **************************************************
# Target word:for
# Context word:['representation', 'distributed', 'words', 'bengio']
# **************************************************
# Target word:words
# Context word:['for', 'representation', 'bengio', 'et']
# **************************************************
# Target word:bengio
# Context word:['words', 'for', 'et', 'al']
# **************************************************
# Target word:et
# Context word:['bengio', 'words', 'al', 'word']
# **************************************************
# Target word:al
# Context word:['et', 'bengio', 'word', 'embeddings']
# **************************************************
# Target word:word
# Context word:['al', 'et', 'embeddings', 'come']
# **************************************************
# Target word:embeddings
# Context word:['word', 'al', 'come', 'in']
# **************************************************
# Target word:come
# Context word:['embeddings', 'word', 'in', 'two']
# **************************************************
# Target word:in
# Context word:['come', 'embeddings', 'two', 'different']
# **************************************************
# Target word:two
# Context word:['in', 'come', 'different', 'styles']
# **************************************************
# Target word:different
# Context word:['two', 'in', 'styles', 'one']
# **************************************************
# Target word:styles
# Context word:['different', 'two', 'one', 'in']
# **************************************************
# Target word:one
# Context word:['styles', 'different', 'in', 'which']
# **************************************************
# Target word:in
# Context word:['one', 'styles', 'which', 'words']
# **************************************************
# Target word:which
# Context word:['in', 'one', 'words', 'are']
# **************************************************
# Target word:words
# Context word:['which', 'in', 'are', 'expressed']
# **************************************************
# Target word:are
# Context word:['words', 'which', 'expressed', 'as']
# **************************************************
# Target word:expressed
# Context word:['are', 'words', 'as', 'vectors']
# **************************************************
# Target word:as
# Context word:['expressed', 'are', 'vectors', 'of']
# **************************************************
# Target word:vectors
# Context word:['as', 'expressed', 'of', 'co']
# **************************************************
# Target word:of
# Context word:['vectors', 'as', 'co', 'occurring']
# **************************************************
# Target word:co
# Context word:['of', 'vectors', 'occurring', 'words']
# **************************************************
# Target word:occurring
# Context word:['co', 'of', 'words', 'and']
# **************************************************
# Target word:words
# Context word:['occurring', 'co', 'and', 'another']
# **************************************************
# Target word:and
# Context word:['words', 'occurring', 'another', 'in']
# **************************************************
# Target word:another
# Context word:['and', 'words', 'in', 'which']
# **************************************************
# Target word:in
# Context word:['another', 'and', 'which', 'words']
# **************************************************
# Target word:which
# Context word:['in', 'another', 'words', 'are']
# **************************************************
# Target word:words
# Context word:['which', 'in', 'are', 'expressed']
# **************************************************
# Target word:are
# Context word:['words', 'which', 'expressed', 'as']
# **************************************************
# Target word:expressed
# Context word:['are', 'words', 'as', 'vectors']
# **************************************************
# Target word:as
# Context word:['expressed', 'are', 'vectors', 'of']
# **************************************************
# Target word:vectors
# Context word:['as', 'expressed', 'of', 'linguistic']
# **************************************************
# Target word:of
# Context word:['vectors', 'as', 'linguistic', 'contexts']
# **************************************************
# Target word:linguistic
# Context word:['of', 'vectors', 'contexts', 'in']
# **************************************************
# Target word:contexts
# Context word:['linguistic', 'of', 'in', 'which']
# **************************************************
# Target word:in
# Context word:['contexts', 'linguistic', 'which', 'the']
# **************************************************
# Target word:which
# Context word:['in', 'contexts', 'the', 'words']
# **************************************************
# Target word:the
# Context word:['which', 'in', 'words', 'occur']
# **************************************************
# Target word:words
# Context word:['the', 'which', 'occur', 'these']
# **************************************************
# Target word:occur
# Context word:['words', 'the', 'these', 'different']
# **************************************************
# Target word:these
# Context word:['occur', 'words', 'different', 'styles']
# **************************************************
# Target word:different
# Context word:['these', 'occur', 'styles', 'are']
# **************************************************
# Target word:styles
# Context word:['different', 'these', 'are', 'studied']
# **************************************************
# Target word:are
# Context word:['styles', 'different', 'studied', 'in']
# **************************************************
# Target word:studied
# Context word:['are', 'styles', 'in', 'lavelli']
# **************************************************
# Target word:in
# Context word:['studied', 'are', 'lavelli', 'et']
# **************************************************
# Target word:lavelli
# Context word:['in', 'studied', 'et', 'al']
# **************************************************
# Target word:et
# Context word:['lavelli', 'in', 'al', 'roweis']
# **************************************************
# Target word:al
# Context word:['et', 'lavelli', 'roweis', 'and']
# **************************************************
# Target word:roweis
# Context word:['al', 'et', 'and', 'saul']
# **************************************************
# Target word:and
# Context word:['roweis', 'al', 'saul', 'published']
# **************************************************
# Target word:saul
# Context word:['and', 'roweis', 'published', 'in']
# **************************************************
# Target word:published
# Context word:['saul', 'and', 'in', 'science']
# **************************************************
# Target word:in
# Context word:['published', 'saul', 'science', 'how']
# **************************************************
# Target word:science
# Context word:['in', 'published', 'how', 'to']
# **************************************************
# Target word:how
# Context word:['science', 'in', 'to', 'use']
# **************************************************
# Target word:to
# Context word:['how', 'science', 'use', 'locally']
# **************************************************
# Target word:use
# Context word:['to', 'how', 'locally', 'linear']
# **************************************************
# Target word:locally
# Context word:['use', 'to', 'linear', 'embedding']
# **************************************************
# Target word:linear
# Context word:['locally', 'use', 'embedding', 'lle']
# **************************************************
# Target word:embedding
# Context word:['linear', 'locally', 'lle', 'to']
# **************************************************
# Target word:lle
# Context word:['embedding', 'linear', 'to', 'discover']
# **************************************************
# Target word:to
# Context word:['lle', 'embedding', 'discover', 'representations']
# **************************************************
# Target word:discover
# Context word:['to', 'lle', 'representations', 'of']
# **************************************************
# Target word:representations
# Context word:['discover', 'to', 'of', 'high']
# **************************************************
# Target word:of
# Context word:['representations', 'discover', 'high', 'dimensional']
# **************************************************
# Target word:high
# Context word:['of', 'representations', 'dimensional', 'data']
# **************************************************
# Target word:dimensional
# Context word:['high', 'of', 'data', 'structures']
# **************************************************
# Target word:data
# Context word:['dimensional', 'high', 'structures', 'the']
# **************************************************
# Target word:structures
# Context word:['data', 'dimensional', 'the', 'area']
# **************************************************
# Target word:the
# Context word:['structures', 'data', 'area', 'developed']
# **************************************************
# Target word:area
# Context word:['the', 'structures', 'developed', 'gradually']
# **************************************************
# Target word:developed
# Context word:['area', 'the', 'gradually', 'and']
# **************************************************
# Target word:gradually
# Context word:['developed', 'area', 'and', 'really']
# **************************************************
# Target word:and
# Context word:['gradually', 'developed', 'really', 'took']
# **************************************************
# Target word:really
# Context word:['and', 'gradually', 'took', 'off']
# **************************************************
# Target word:took
# Context word:['really', 'and', 'off', 'after']
# **************************************************
# Target word:off
# Context word:['took', 'really', 'after', 'partly']
# **************************************************
# Target word:after
# Context word:['off', 'took', 'partly', 'because']
# **************************************************
# Target word:partly
# Context word:['after', 'off', 'because', 'important']
# **************************************************
# Target word:because
# Context word:['partly', 'after', 'important', 'advances']
# **************************************************
# Target word:important
# Context word:['because', 'partly', 'advances', 'had']
# **************************************************
# Target word:advances
# Context word:['important', 'because', 'had', 'been']
# **************************************************
# Target word:had
# Context word:['advances', 'important', 'been', 'made']
# **************************************************
# Target word:been
# Context word:['had', 'advances', 'made', 'since']
# **************************************************
# Target word:made
# Context word:['been', 'had', 'since', 'then']
# **************************************************
# Target word:since
# Context word:['made', 'been', 'then', 'on']
# **************************************************
# Target word:then
# Context word:['since', 'made', 'on', 'the']
# **************************************************
# Target word:on
# Context word:['then', 'since', 'the', 'quality']
# **************************************************
# Target word:the
# Context word:['on', 'then', 'quality', 'of']
# **************************************************
# Target word:quality
# Context word:['the', 'on', 'of', 'vectors']
# **************************************************
# Target word:of
# Context word:['quality', 'the', 'vectors', 'and']
# **************************************************
# Target word:vectors
# Context word:['of', 'quality', 'and', 'the']
# **************************************************
# Target word:and
# Context word:['vectors', 'of', 'the', 'training']
# **************************************************
# Target word:the
# Context word:['and', 'vectors', 'training', 'speed']
# **************************************************
# Target word:training
# Context word:['the', 'and', 'speed', 'of']
# **************************************************
# Target word:speed
# Context word:['training', 'the', 'of', 'the']
# **************************************************
# Target word:of
# Context word:['speed', 'training', 'the', 'model']
# **************************************************
# Target word:the
# Context word:['of', 'speed', 'model', 'there']
# **************************************************
# Target word:model
# Context word:['the', 'of', 'there', 'are']
# **************************************************
# Target word:there
# Context word:['model', 'the', 'are', 'many']
# **************************************************
# Target word:are
# Context word:['there', 'model', 'many', 'branches']
# **************************************************
# Target word:many
# Context word:['are', 'there', 'branches', 'and']
# **************************************************
# Target word:branches
# Context word:['many', 'are', 'and', 'many']
# **************************************************
# Target word:and
# Context word:['branches', 'many', 'many', 'research']
# **************************************************
# Target word:many
# Context word:['and', 'branches', 'research', 'groups']
# **************************************************
# Target word:research
# Context word:['many', 'and', 'groups', 'working']
# **************************************************
# Target word:groups
# Context word:['research', 'many', 'working', 'on']
# **************************************************
# Target word:working
# Context word:['groups', 'research', 'on', 'word']
# **************************************************
# Target word:on
# Context word:['working', 'groups', 'word', 'embeddings']
# **************************************************
# Target word:word
# Context word:['on', 'working', 'embeddings', 'in']
# **************************************************
# Target word:embeddings
# Context word:['word', 'on', 'in', 'team']
# **************************************************
# Target word:in
# Context word:['embeddings', 'word', 'team', 'at']
# **************************************************
# Target word:team
# Context word:['in', 'embeddings', 'at', 'google']
# **************************************************
# Target word:at
# Context word:['team', 'in', 'google', 'led']
# **************************************************
# Target word:google
# Context word:['at', 'team', 'led', 'by']
# **************************************************
# Target word:led
# Context word:['google', 'at', 'by', 'tomas']
# **************************************************
# Target word:by
# Context word:['led', 'google', 'tomas', 'mikolov']
# **************************************************
# Target word:tomas
# Context word:['by', 'led', 'mikolov', 'created']
# **************************************************
# Target word:mikolov
# Context word:['tomas', 'by', 'created', 'word']
# **************************************************
# Target word:created
# Context word:['mikolov', 'tomas', 'word', 'vec']
# **************************************************
# Target word:word
# Context word:['created', 'mikolov', 'vec', 'word']
# **************************************************
# Target word:vec
# Context word:['word', 'created', 'word', 'embedding']
# **************************************************
# Target word:word
# Context word:['vec', 'word', 'embedding', 'toolkit']
# **************************************************
# Target word:embedding
# Context word:['word', 'vec', 'toolkit', 'which']
# **************************************************
# Target word:toolkit
# Context word:['embedding', 'word', 'which', 'can']
# **************************************************
# Target word:which
# Context word:['toolkit', 'embedding', 'can', 'train']
# **************************************************
# Target word:can
# Context word:['which', 'toolkit', 'train', 'vector']
# **************************************************
# Target word:train
# Context word:['can', 'which', 'vector', 'space']
# **************************************************
# Target word:vector
# Context word:['train', 'can', 'space', 'models']
# **************************************************
# Target word:space
# Context word:['vector', 'train', 'models', 'faster']
# **************************************************
# Target word:models
# Context word:['space', 'vector', 'faster', 'than']
# **************************************************
# Target word:faster
# Context word:['models', 'space', 'than', 'the']
# **************************************************
# Target word:than
# Context word:['faster', 'models', 'the', 'previous']
# **************************************************
# Target word:the
# Context word:['than', 'faster', 'previous', 'approaches']
# **************************************************
# Target word:previous
# Context word:['the', 'than', 'approaches', 'most']
# **************************************************
# Target word:approaches
# Context word:['previous', 'the', 'most', 'new']
# **************************************************
# Target word:most
# Context word:['approaches', 'previous', 'new', 'word']
# **************************************************
# Target word:new
# Context word:['most', 'approaches', 'word', 'embedding']
# **************************************************
# Target word:word
# Context word:['new', 'most', 'embedding', 'techniques']
# **************************************************
# Target word:embedding
# Context word:['word', 'new', 'techniques', 'rely']
# **************************************************
# Target word:techniques
# Context word:['embedding', 'word', 'rely', 'on']
# **************************************************
# Target word:rely
# Context word:['techniques', 'embedding', 'on', 'neural']
# **************************************************
# Target word:on
# Context word:['rely', 'techniques', 'neural', 'network']
# **************************************************
# Target word:neural
# Context word:['on', 'rely', 'network', 'architecture']
# **************************************************
# Target word:network
# Context word:['neural', 'on', 'architecture', 'instead']
# **************************************************
# Target word:architecture
# Context word:['network', 'neural', 'instead', 'of']
# **************************************************
# Target word:instead
# Context word:['architecture', 'network', 'of', 'more']
# **************************************************
# Target word:of
# Context word:['instead', 'architecture', 'more', 'traditional']
# **************************************************
# Target word:more
# Context word:['of', 'instead', 'traditional', 'gram']
# **************************************************
# Target word:traditional
# Context word:['more', 'of', 'gram', 'models']
# **************************************************
# Target word:gram
# Context word:['traditional', 'more', 'models', 'and']
# **************************************************
# Target word:models
# Context word:['gram', 'traditional', 'and', 'unsupervised']
# **************************************************
# Target word:and
# Context word:['models', 'gram', 'unsupervised', 'learning']
# **************************************************
# Target word:unsupervised
# Context word:['and', 'models', 'learning', 'limitations']
# **************************************************
# Target word:learning
# Context word:['unsupervised', 'and', 'limitations', 'one']
# **************************************************
# Target word:limitations
# Context word:['learning', 'unsupervised', 'one', 'of']
# **************************************************
# Target word:one
# Context word:['limitations', 'learning', 'of', 'the']
# **************************************************
# Target word:of
# Context word:['one', 'limitations', 'the', 'main']
# **************************************************
# Target word:the
# Context word:['of', 'one', 'main', 'limitations']
# **************************************************
# Target word:main
# Context word:['the', 'of', 'limitations', 'of']
# **************************************************
# Target word:limitations
# Context word:['main', 'the', 'of', 'word']
# **************************************************
# Target word:of
# Context word:['limitations', 'main', 'word', 'embeddings']
# **************************************************
# Target word:word
# Context word:['of', 'limitations', 'embeddings', 'word']
# **************************************************
# Target word:embeddings
# Context word:['word', 'of', 'word', 'vector']
# **************************************************
# Target word:word
# Context word:['embeddings', 'word', 'vector', 'space']
# **************************************************
# Target word:vector
# Context word:['word', 'embeddings', 'space', 'models']
# **************************************************
# Target word:space
# Context word:['vector', 'word', 'models', 'in']
# **************************************************
# Target word:models
# Context word:['space', 'vector', 'in', 'general']
# **************************************************
# Target word:in
# Context word:['models', 'space', 'general', 'is']
# **************************************************
# Target word:general
# Context word:['in', 'models', 'is', 'that']
# **************************************************
# Target word:is
# Context word:['general', 'in', 'that', 'possible']
# **************************************************
# Target word:that
# Context word:['is', 'general', 'possible', 'meanings']
# **************************************************
# Target word:possible
# Context word:['that', 'is', 'meanings', 'of']
# **************************************************
# Target word:meanings
# Context word:['possible', 'that', 'of', 'word']
# **************************************************
# Target word:of
# Context word:['meanings', 'possible', 'word', 'are']
# **************************************************
# Target word:word
# Context word:['of', 'meanings', 'are', 'conflated']
# **************************************************
# Target word:are
# Context word:['word', 'of', 'conflated', 'into']
# **************************************************
# Target word:conflated
# Context word:['are', 'word', 'into', 'single']
# **************************************************
# Target word:into
# Context word:['conflated', 'are', 'single', 'representation']
# **************************************************
# Target word:single
# Context word:['into', 'conflated', 'representation', 'single']
# **************************************************
# Target word:representation
# Context word:['single', 'into', 'single', 'vector']
# **************************************************
# Target word:single
# Context word:['representation', 'single', 'vector', 'in']
# **************************************************
# Target word:vector
# Context word:['single', 'representation', 'in', 'the']
# **************************************************
# Target word:in
# Context word:['vector', 'single', 'the', 'semantic']
# **************************************************
# Target word:the
# Context word:['in', 'vector', 'semantic', 'space']
# **************************************************
# Target word:semantic
# Context word:['the', 'in', 'space', 'sense']
# **************************************************
# Target word:space
# Context word:['semantic', 'the', 'sense', 'embeddings']
# **************************************************
# Target word:sense
# Context word:['space', 'semantic', 'embeddings', 'are']
# **************************************************
# Target word:embeddings
# Context word:['sense', 'space', 'are', 'solution']
# **************************************************
# Target word:are
# Context word:['embeddings', 'sense', 'solution', 'to']
# **************************************************
# Target word:solution
# Context word:['are', 'embeddings', 'to', 'this']
# **************************************************
# Target word:to
# Context word:['solution', 'are', 'this', 'problem']
# **************************************************
# Target word:this
# Context word:['to', 'solution', 'problem', 'individual']
# **************************************************
# Target word:problem
# Context word:['this', 'to', 'individual', 'meanings']
# **************************************************
# Target word:individual
# Context word:['problem', 'this', 'meanings', 'of']
# **************************************************
# Target word:meanings
# Context word:['individual', 'problem', 'of', 'words']
# **************************************************
# Target word:of
# Context word:['meanings', 'individual', 'words', 'are']
# **************************************************
# Target word:words
# Context word:['of', 'meanings', 'are', 'represented']
# **************************************************
# Target word:are
# Context word:['words', 'of', 'represented', 'as']
# **************************************************
# Target word:represented
# Context word:['are', 'words', 'as', 'distinct']
# **************************************************
# Target word:as
# Context word:['represented', 'are', 'distinct', 'vectors']
# **************************************************
# Target word:distinct
# Context word:['as', 'represented', 'vectors', 'in']
# **************************************************
# Target word:vectors
# Context word:['distinct', 'as', 'in', 'the']
# **************************************************
# Target word:in
# Context word:['vectors', 'distinct', 'the', 'space']
# **************************************************
# Target word:the
# Context word:['in', 'vectors', 'space', 'for']
# **************************************************
# Target word:space
# Context word:['the', 'in', 'for', 'biological']
# **************************************************
# Target word:for
# Context word:['space', 'the', 'biological', 'sequences']
# **************************************************
# Target word:biological
# Context word:['for', 'space', 'sequences', 'biovectors']
# **************************************************
# Target word:sequences
# Context word:['biological', 'for', 'biovectors', 'word']
# **************************************************
# Target word:biovectors
# Context word:['sequences', 'biological', 'word', 'embeddings']
# **************************************************
# Target word:word
# Context word:['biovectors', 'sequences', 'embeddings', 'for']
# **************************************************
# Target word:embeddings
# Context word:['word', 'biovectors', 'for', 'grams']
# **************************************************
# Target word:for
# Context word:['embeddings', 'word', 'grams', 'in']
# **************************************************
# Target word:grams
# Context word:['for', 'embeddings', 'in', 'biological']
# **************************************************
# Target word:in
# Context word:['grams', 'for', 'biological', 'sequences']
# **************************************************
# Target word:biological
# Context word:['in', 'grams', 'sequences', 'dna']
# **************************************************
# Target word:sequences
# Context word:['biological', 'in', 'dna', 'rna']
# **************************************************
# Target word:dna
# Context word:['sequences', 'biological', 'rna', 'and']
# **************************************************
# Target word:rna
# Context word:['dna', 'sequences', 'and', 'proteins']
# **************************************************
# Target word:and
# Context word:['rna', 'dna', 'proteins', 'for']
# **************************************************
# Target word:proteins
# Context word:['and', 'rna', 'for', 'bioinformatics']
# **************************************************
# Target word:for
# Context word:['proteins', 'and', 'bioinformatics', 'applications']
# **************************************************
# Target word:bioinformatics
# Context word:['for', 'proteins', 'applications', 'have']
# **************************************************
# Target word:applications
# Context word:['bioinformatics', 'for', 'have', 'been']
# **************************************************
# Target word:have
# Context word:['applications', 'bioinformatics', 'been', 'proposed']
# **************************************************
# Target word:been
# Context word:['have', 'applications', 'proposed', 'by']
# **************************************************
# Target word:proposed
# Context word:['been', 'have', 'by', 'asgari']
# **************************************************
# Target word:by
# Context word:['proposed', 'been', 'asgari', 'and']
# **************************************************
# Target word:asgari
# Context word:['by', 'proposed', 'and', 'mofrad']
# **************************************************
# Target word:and
# Context word:['asgari', 'by', 'mofrad', 'named']
# **************************************************
# Target word:mofrad
# Context word:['and', 'asgari', 'named', 'bio']
# **************************************************
# Target word:named
# Context word:['mofrad', 'and', 'bio', 'vectors']
# **************************************************
# Target word:bio
# Context word:['named', 'mofrad', 'vectors', 'biovec']
# **************************************************
# Target word:vectors
# Context word:['bio', 'named', 'biovec', 'to']
# **************************************************
# Target word:biovec
# Context word:['vectors', 'bio', 'to', 'refer']
# **************************************************
# Target word:to
# Context word:['biovec', 'vectors', 'refer', 'to']
# **************************************************
# Target word:refer
# Context word:['to', 'biovec', 'to', 'biological']
# **************************************************
# Target word:to
# Context word:['refer', 'to', 'biological', 'sequences']
# **************************************************
# Target word:biological
# Context word:['to', 'refer', 'sequences', 'in']
# **************************************************
# Target word:sequences
# Context word:['biological', 'to', 'in', 'general']
# **************************************************
# Target word:in
# Context word:['sequences', 'biological', 'general', 'with']
# **************************************************
# Target word:general
# Context word:['in', 'sequences', 'with', 'protein']
# **************************************************
# Target word:with
# Context word:['general', 'in', 'protein', 'vectors']
# **************************************************
# Target word:protein
# Context word:['with', 'general', 'vectors', 'protvec']
# **************************************************
# Target word:vectors
# Context word:['protein', 'with', 'protvec', 'for']
# **************************************************
# Target word:protvec
# Context word:['vectors', 'protein', 'for', 'proteins']
# **************************************************
# Target word:for
# Context word:['protvec', 'vectors', 'proteins', 'amino']
# **************************************************
# Target word:proteins
# Context word:['for', 'protvec', 'amino', 'acid']
# **************************************************
# Target word:amino
# Context word:['proteins', 'for', 'acid', 'sequences']
# **************************************************
# Target word:acid
# Context word:['amino', 'proteins', 'sequences', 'and']
# **************************************************
# Target word:sequences
# Context word:['acid', 'amino', 'and', 'gene']
# **************************************************
# Target word:and
# Context word:['sequences', 'acid', 'gene', 'vectors']
# **************************************************
# Target word:gene
# Context word:['and', 'sequences', 'vectors', 'genevec']
# **************************************************
# Target word:vectors
# Context word:['gene', 'and', 'genevec', 'for']
# **************************************************
# Target word:genevec
# Context word:['vectors', 'gene', 'for', 'gene']
# **************************************************
# Target word:for
# Context word:['genevec', 'vectors', 'gene', 'sequences']
# **************************************************
# Target word:gene
# Context word:['for', 'genevec', 'sequences', 'this']
# **************************************************
# Target word:sequences
# Context word:['gene', 'for', 'this', 'representation']
# **************************************************
# Target word:this
# Context word:['sequences', 'gene', 'representation', 'can']
# **************************************************
# Target word:representation
# Context word:['this', 'sequences', 'can', 'be']
# **************************************************
# Target word:can
# Context word:['representation', 'this', 'be', 'widely']
# **************************************************
# Target word:be
# Context word:['can', 'representation', 'widely', 'used']
# **************************************************
# Target word:widely
# Context word:['be', 'can', 'used', 'in']
# **************************************************
# Target word:used
# Context word:['widely', 'be', 'in', 'applications']
# **************************************************
# Target word:in
# Context word:['used', 'widely', 'applications', 'of']
# **************************************************
# Target word:applications
# Context word:['in', 'used', 'of', 'deep']
# **************************************************
# Target word:of
# Context word:['applications', 'in', 'deep', 'learning']
# **************************************************
# Target word:deep
# Context word:['of', 'applications', 'learning', 'in']
# **************************************************
# Target word:learning
# Context word:['deep', 'of', 'in', 'proteomics']
# **************************************************
# Target word:in
# Context word:['learning', 'deep', 'proteomics', 'and']
# **************************************************
# Target word:proteomics
# Context word:['in', 'learning', 'and', 'genomics']
# **************************************************
# Target word:and
# Context word:['proteomics', 'in', 'genomics', 'the']
# **************************************************
# Target word:genomics
# Context word:['and', 'proteomics', 'the', 'results']
# **************************************************
# Target word:the
# Context word:['genomics', 'and', 'results', 'presented']
# **************************************************
# Target word:results
# Context word:['the', 'genomics', 'presented', 'by']
# **************************************************
# Target word:presented
# Context word:['results', 'the', 'by', 'asgari']
# **************************************************
# Target word:by
# Context word:['presented', 'results', 'asgari', 'and']
# **************************************************
# Target word:asgari
# Context word:['by', 'presented', 'and', 'mofrad']
# **************************************************
# Target word:and
# Context word:['asgari', 'by', 'mofrad', 'suggest']
# **************************************************
# Target word:mofrad
# Context word:['and', 'asgari', 'suggest', 'that']
# **************************************************
# Target word:suggest
# Context word:['mofrad', 'and', 'that', 'biovectors']
# **************************************************
# Target word:that
# Context word:['suggest', 'mofrad', 'biovectors', 'can']
# **************************************************
# Target word:biovectors
# Context word:['that', 'suggest', 'can', 'characterize']
# **************************************************
# Target word:can
# Context word:['biovectors', 'that', 'characterize', 'biological']
# **************************************************
# Target word:characterize
# Context word:['can', 'biovectors', 'biological', 'sequences']
# **************************************************
# Target word:biological
# Context word:['characterize', 'can', 'sequences', 'in']
# **************************************************
# Target word:sequences
# Context word:['biological', 'characterize', 'in', 'terms']
# **************************************************
# Target word:in
# Context word:['sequences', 'biological', 'terms', 'of']
# **************************************************
# Target word:terms
# Context word:['in', 'sequences', 'of', 'biochemical']
# **************************************************
# Target word:of
# Context word:['terms', 'in', 'biochemical', 'and']
# **************************************************
# Target word:biochemical
# Context word:['of', 'terms', 'and', 'biophysical']
# **************************************************
# Target word:and
# Context word:['biochemical', 'of', 'biophysical', 'interpretations']
# **************************************************
# Target word:biophysical
# Context word:['and', 'biochemical', 'interpretations', 'of']
# **************************************************
# Target word:interpretations
# Context word:['biophysical', 'and', 'of', 'the']
# **************************************************
# Target word:of
# Context word:['interpretations', 'biophysical', 'the', 'underlying']
# **************************************************
# Target word:the
# Context word:['of', 'interpretations', 'underlying', 'patterns']
# **************************************************
# Target word:underlying
# Context word:['the', 'of', 'patterns', 'thought']
# **************************************************
# Target word:patterns
# Context word:['underlying', 'the', 'thought', 'vectors']
# **************************************************
# Target word:thought
# Context word:['patterns', 'underlying', 'vectors', 'thought']
# **************************************************
# Target word:vectors
# Context word:['thought', 'patterns', 'thought', 'vectors']
# **************************************************
# Target word:thought
# Context word:['vectors', 'thought', 'vectors', 'are']
# **************************************************
# Target word:vectors
# Context word:['thought', 'vectors', 'are', 'an']
# **************************************************
# Target word:are
# Context word:['vectors', 'thought', 'an', 'extension']
# **************************************************
# Target word:an
# Context word:['are', 'vectors', 'extension', 'of']
# **************************************************
# Target word:extension
# Context word:['an', 'are', 'of', 'word']
# **************************************************
# Target word:of
# Context word:['extension', 'an', 'word', 'embeddings']
# **************************************************
# Target word:word
# Context word:['of', 'extension', 'embeddings', 'to']
# **************************************************
# Target word:embeddings
# Context word:['word', 'of', 'to', 'entire']
# **************************************************
# Target word:to
# Context word:['embeddings', 'word', 'entire', 'sentences']
# **************************************************
# Target word:entire
# Context word:['to', 'embeddings', 'sentences', 'or']
# **************************************************
# Target word:sentences
# Context word:['entire', 'to', 'or', 'even']
# **************************************************
# Target word:or
# Context word:['sentences', 'entire', 'even', 'documents']
# **************************************************
# Target word:even
# Context word:['or', 'sentences', 'documents', 'some']
# **************************************************
# Target word:documents
# Context word:['even', 'or', 'some', 'researchers']
# **************************************************
# Target word:some
# Context word:['documents', 'even', 'researchers', 'hope']
# **************************************************
# Target word:researchers
# Context word:['some', 'documents', 'hope', 'that']
# **************************************************
# Target word:hope
# Context word:['researchers', 'some', 'that', 'these']
# **************************************************
# Target word:that
# Context word:['hope', 'researchers', 'these', 'can']
# **************************************************
# Target word:these
# Context word:['that', 'hope', 'can', 'improve']
# **************************************************
# Target word:can
# Context word:['these', 'that', 'improve', 'the']
# **************************************************
# Target word:improve
# Context word:['can', 'these', 'the', 'quality']
# **************************************************
# Target word:the
# Context word:['improve', 'can', 'quality', 'of']
# **************************************************
# Target word:quality
# Context word:['the', 'improve', 'of', 'machine']
# **************************************************
# Target word:of
# Context word:['quality', 'the', 'machine', 'translation']
# **************************************************
# Target word:machine
# Context word:['of', 'quality', 'translation', 'software']
# **************************************************
# Target word:translation
# Context word:['machine', 'of', 'software', 'software']
# **************************************************
# Target word:software
# Context word:['translation', 'machine', 'software', 'for']
# **************************************************
# Target word:software
# Context word:['software', 'translation', 'for', 'training']
# **************************************************
# Target word:for
# Context word:['software', 'software', 'training', 'and']
# **************************************************
# Target word:training
# Context word:['for', 'software', 'and', 'using']
# **************************************************
# Target word:and
# Context word:['training', 'for', 'using', 'word']
# **************************************************
# Target word:using
# Context word:['and', 'training', 'word', 'embeddings']
# **************************************************
# Target word:word
# Context word:['using', 'and', 'embeddings', 'includes']
# **************************************************
# Target word:embeddings
# Context word:['word', 'using', 'includes', 'tomas']
# **************************************************
# Target word:includes
# Context word:['embeddings', 'word', 'tomas', 'mikolov']
# **************************************************
# Target word:tomas
# Context word:['includes', 'embeddings', 'mikolov', 'word']
# **************************************************
# Target word:mikolov
# Context word:['tomas', 'includes', 'word', 'vec']
# **************************************************
# Target word:word
# Context word:['mikolov', 'tomas', 'vec', 'stanford']
# **************************************************
# Target word:vec
# Context word:['word', 'mikolov', 'stanford', 'university']
# **************************************************
# Target word:stanford
# Context word:['vec', 'word', 'university', 'glove']
# **************************************************
# Target word:university
# Context word:['stanford', 'vec', 'glove', 'allennlp']
# **************************************************
# Target word:glove
# Context word:['university', 'stanford', 'allennlp', 'elmo']
# **************************************************
# Target word:allennlp
# Context word:['glove', 'university', 'elmo', 'fasttext']
# **************************************************
# Target word:elmo
# Context word:['allennlp', 'glove', 'fasttext', 'gensim']
# **************************************************
# Target word:fasttext
# Context word:['elmo', 'allennlp', 'gensim', 'indra']
# **************************************************
# Target word:gensim
# Context word:['fasttext', 'elmo', 'indra', 'and']
# **************************************************
# Target word:indra
# Context word:['gensim', 'fasttext', 'and', 'deeplearning']
# **************************************************
# Target word:and
# Context word:['indra', 'gensim', 'deeplearning', 'principal']
# **************************************************
# Target word:deeplearning
# Context word:['and', 'indra', 'principal', 'component']
# **************************************************
# Target word:principal
# Context word:['deeplearning', 'and', 'component', 'analysis']
# **************************************************
# Target word:component
# Context word:['principal', 'deeplearning', 'analysis', 'pca']
# **************************************************
# Target word:analysis
# Context word:['component', 'principal', 'pca', 'and']
# **************************************************
# Target word:pca
# Context word:['analysis', 'component', 'and', 'distributed']
# **************************************************
# Target word:and
# Context word:['pca', 'analysis', 'distributed', 'stochastic']
# **************************************************
# Target word:distributed
# Context word:['and', 'pca', 'stochastic', 'neighbour']
# **************************************************
# Target word:stochastic
# Context word:['distributed', 'and', 'neighbour', 'embedding']
# **************************************************
# Target word:neighbour
# Context word:['stochastic', 'distributed', 'embedding', 'sne']
# **************************************************
# Target word:embedding
# Context word:['neighbour', 'stochastic', 'sne', 'are']
# **************************************************
# Target word:sne
# Context word:['embedding', 'neighbour', 'are', 'both']
# **************************************************
# Target word:are
# Context word:['sne', 'embedding', 'both', 'used']
# **************************************************
# Target word:both
# Context word:['are', 'sne', 'used', 'to']
# **************************************************
# Target word:used
# Context word:['both', 'are', 'to', 'reduce']
# **************************************************
# Target word:to
# Context word:['used', 'both', 'reduce', 'the']
# **************************************************
# Target word:reduce
# Context word:['to', 'used', 'the', 'dimensionality']
# **************************************************
# Target word:the
# Context word:['reduce', 'to', 'dimensionality', 'of']
# **************************************************
# Target word:dimensionality
# Context word:['the', 'reduce', 'of', 'word']
# **************************************************
# Target word:of
# Context word:['dimensionality', 'the', 'word', 'vector']
# **************************************************
# Target word:word
# Context word:['of', 'dimensionality', 'vector', 'spaces']
# **************************************************
# Target word:vector
# Context word:['word', 'of', 'spaces', 'and']
# **************************************************
# Target word:spaces
# Context word:['vector', 'word', 'and', 'visualize']
# **************************************************
# Target word:and
# Context word:['spaces', 'vector', 'visualize', 'word']
# **************************************************
# Target word:visualize
# Context word:['and', 'spaces', 'word', 'embeddings']
# **************************************************
# Target word:word
# Context word:['visualize', 'and', 'embeddings', 'and']
# **************************************************
# Target word:embeddings
# Context word:['word', 'visualize', 'and', 'clusters']
# **************************************************
# Target word:and
# Context word:['embeddings', 'word', 'clusters', 'examples']
# **************************************************
# Target word:clusters
# Context word:['and', 'embeddings', 'examples', 'of']
# **************************************************
# Target word:examples
# Context word:['clusters', 'and', 'of', 'application']
# **************************************************
# Target word:of
# Context word:['examples', 'clusters', 'application', 'for']
# **************************************************
# Target word:application
# Context word:['of', 'examples', 'for', 'instance']
# **************************************************
# Target word:for
# Context word:['application', 'of', 'instance', 'the']
# **************************************************
# Target word:instance
# Context word:['for', 'application', 'the', 'fasttext']
# **************************************************
# Target word:the
# Context word:['instance', 'for', 'fasttext', 'is']
# **************************************************
# Target word:fasttext
# Context word:['the', 'instance', 'is', 'also']
# **************************************************
# Target word:is
# Context word:['fasttext', 'the', 'also', 'used']
# **************************************************
# Target word:also
# Context word:['is', 'fasttext', 'used', 'to']
# **************************************************
# Target word:used
# Context word:['also', 'is', 'to', 'calculate']
# **************************************************
# Target word:to
# Context word:['used', 'also', 'calculate', 'word']
# **************************************************
# Target word:calculate
# Context word:['to', 'used', 'word', 'embeddings']
# **************************************************
# Target word:word
# Context word:['calculate', 'to', 'embeddings', 'for']
# **************************************************
# Target word:embeddings
# Context word:['word', 'calculate', 'for', 'text']
# **************************************************
# Target word:for
# Context word:['embeddings', 'word', 'text', 'corpora']
# **************************************************
# Target word:text
# Context word:['for', 'embeddings', 'corpora', 'in']
# **************************************************
# Target word:corpora
# Context word:['text', 'for', 'in', 'sketch']
# **************************************************
# Target word:in
# Context word:['corpora', 'text', 'sketch', 'engine']
# **************************************************
# Target word:sketch
# Context word:['in', 'corpora', 'engine', 'that']
# **************************************************
# Target word:engine
# Context word:['sketch', 'in', 'that', 'are']
# **************************************************
# Target word:that
# Context word:['engine', 'sketch', 'are', 'available']
# **************************************************
# Target word:are
# Context word:['that', 'engine', 'available', 'online']
# **************************************************
# Target word:available
# Context word:['are', 'that', 'online']
# **************************************************
# Target word:online
# Context word:['available', 'are']
